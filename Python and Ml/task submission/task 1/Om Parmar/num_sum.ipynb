# %%
import random
sum=0
for i in range(10):
    s=random.randint(1,100)
    print("number", i, ": ", s)
    sum += s
# Out:
# number 0 :  98
# number 1 :  91
# number 2 :  24
# number 3 :  59
# number 4 :  16
# number 5 :  1
# number 6 :  49
# number 7 :  33
# number 8 :  63
# number 9 :  77

# %%
print("Sum of random numbers :",sum)
# Out:
# Sum of random numbers : 511
