# %%
words = input("enter words separated by spaces:")
sort = words.split()
sort.sort()
print(sort)
# Out:
# enter words separated by spaces: valo pubg cod ab fifa
# ['ab', 'cod', 'fifa', 'pubg', 'valo']
