# %%
def add(a,b):
    print(a+b)
def subtract(a,b):
    print(a-b)
def multi(a,b):
    print(a*b)
def divi(a,b):
    print(a/b)
a=int(input("enter a:"))
b=int(input("enter b:"))
Dict={1:'ADD',2:'SUBTACT',3:'MULTIPLY',4:'DIVIDE'}
print(Dict)
n=int(input("Enter a choice:"))
if n==1:
    add(a,b)
elif n==2:
    subtract(a,b)
elif n==3:
    multi(a,b)
else: divi(a,b)
# Out:
# enter a: 1
# enter b: 8
# {1: 'ADD', 2: 'SUBTACT', 3: 'MULTIPLY', 4: 'DIVIDE'}
# Enter a choice: 1
# 9
