# %%
import random

sum_num = 0
print("The 10 random numbrs are: ")
for count in range(10):
    randnums = random.randint(1,100)
    sum_num = sum_num + randnums 
    print(randnums, end='\t')
print("\nThe sum of 10 random numbers are: ",sum_num)
# Out:
# The 10 random numbrs are:
# 96	14	94	98	50	73	20	70	44	79
# The sum of 10 random numbers are:  638
