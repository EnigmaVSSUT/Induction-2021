# %%
x=float(input('enter first number: '))
opr=str(input('enter operator: '))
y=float(input('enter second number: '))
if opr == "+":
    print(x + y)
elif opr == "-":
    print(x - y)
elif opr == "*":
    print(x * y)
elif opr == "/":
    print(x / y)
# Out:
# enter first number:  222.6764
# enter operator:  /
# enter second number:  23532.123
# 0.009462656641731815
