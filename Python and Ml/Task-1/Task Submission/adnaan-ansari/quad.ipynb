# %%
import math
print('enter coefficients in ax^2+bx+c=0:')
a=float(input('a:'))
b=float(input('b:'))
c=float(input('c:'))
d=(b*b-4*a*c)
if d>0:
    print('two roots are:')
    print((-b+math.sqrt(d))/2*a)
    print((-b-math.sqrt(d))/2*a)
elif d==0:
    print('both roots are eql')
    print(-b/2*a)
else:
    print('roots are imagenary')
# Out:
# enter coefficients in ax^2+bx+c=0:
# a: 12
# b: 144
# c: 2
# two roots are:
# -2.0023201887374285
# -1725.9976798112627
