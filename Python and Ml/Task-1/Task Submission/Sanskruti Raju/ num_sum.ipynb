# %%
import random
sum=0
for i in range(10):
    s=random.randint(1,100)
    print("number", i, ": ", s)
    sum += s
# Out:
# number 0 :  50
# number 1 :  15
# number 2 :  92
# number 3 :  21
# number 4 :  57
# number 5 :  17
# number 6 :  62
# number 7 :  10
# number 8 :  99
# number 9 :  4

# %%
print("Sum of random numbers :",sum)
# Out:
# Sum of random numbers : 427
