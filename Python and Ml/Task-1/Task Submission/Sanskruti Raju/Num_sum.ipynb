# %%
import random
sum=0
for i in range(10):
    s=random.randint(1,100)
    print("number", i, ": ", s)
    sum += s
# Out:
# number 0 :  80
# number 1 :  56
# number 2 :  68
# number 3 :  42
# number 4 :  94
# number 5 :  22
# number 6 :  7
# number 7 :  56
# number 8 :  74
# number 9 :  25

# %%
print("Sum of random numbers :",sum)
# Out:
# Sum of random numbers : 524
