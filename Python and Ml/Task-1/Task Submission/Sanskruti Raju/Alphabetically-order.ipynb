# %%
str1 = input("Enter the string: ")
print("Sorted words: ",end =" ")
words = str1.split()
words.sort()
for word in words:
   print(word,end =" ")
# Out:
# Enter the string: Forget not that the earth delights to feel your bare feet and the winds long to play with your hair.
# Sorted words:  Forget and bare delights earth feel feet hair. long not play that the the to to winds with your your
