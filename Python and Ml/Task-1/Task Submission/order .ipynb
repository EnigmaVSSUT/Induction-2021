# %%
my_str = input("Enter a string: ")  
words = my_str.split()   
words.sort()    
for word in words:  
   print(word)
# Out:
# Enter a string:  she has got a new car
# a
# car
# got
# has
# new
# she
