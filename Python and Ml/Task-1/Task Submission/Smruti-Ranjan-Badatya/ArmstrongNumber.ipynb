# %%
a = int(input())
z = a
sums = 0

while a>0:
    sums += (a%10)**3
    a//=10

if sums == z:
    print("This is an Armstrong Number")
else:
    print("This is not an Armstrong Number")
# Out:
# 153
# This is an Armstrong Number
