# %%
words = ["apple","ball"] 
while True:
    words.append(input())
    if input() == ".":
        break
words.sort()

for word in words:
    print(word)
# Out:
# dof
# dough
# cat
# university
# add
# .
# add
# apple
# ball
# cat
# dof
