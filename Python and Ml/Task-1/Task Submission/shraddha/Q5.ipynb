# %%
import random

  
# using random.sample() + sum()
# Random Numbers Summation
res = sum(random.sample(range(1, 50), 10))
  
# printing result
print ("Random number summation list is : " + str(res))
# Out:
# Random number summation list is : 313
