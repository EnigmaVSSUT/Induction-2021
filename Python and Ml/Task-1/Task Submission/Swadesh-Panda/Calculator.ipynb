# %%
i,j=map(int,input("Enter both the numbers separated by comma(,)").split(","))
k=input("Enter the operator: ")
if(k=="+"):
    print(f"{i} + {j} = {i+j}")
elif(k=="-"): 
    print(f"{i} - {j} = {i-j}")
elif(k=="*"):
    print(f"{i} * {j} = {i*j}")   
elif(k=="/"):
    print(f"{i} / {j} = {i/j}")
else:
    print("Invalid operator")
# Out:
# Enter both the numbers separated by comma(,)5,10
# Enter the operator: +
# 5 + 10 = 15
