# %%
i,j=map(int,input("Enter the starting and ending number separated by ,").split(","))
for num in range(i,j + 1):  
   sum = 0  
   t = num  
   while t > 0:  
        k=(t%10) * (t%10) *(t%10)
        sum=k+sum 
        t //= 10  
   if num == sum:  
        print(num)
# Out:
# Enter the starting and ending number separated by ,29,290
# 153
