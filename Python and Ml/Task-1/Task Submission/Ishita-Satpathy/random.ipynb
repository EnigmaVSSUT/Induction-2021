# %%
import random
def main():
    sum_num = 0
    for count in range(10):
        randnom = random.randrange(1,10)
        sum_num = sum_num+randnom
        print(randnom, end="")
    print(sum_num)
    
main()
