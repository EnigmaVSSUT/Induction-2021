# %%
l = int(input("Enter lower range "))
u = int(input("Enter higher range "))
for i in range(l, u+1):
    num = i
    sum = 0
    while num > 0:
        d = num % 10
        sum = sum + d**3
        num //= 10
    int(sum)
    if(sum == i):
        print(sum)
# Out:
# Enter lower range  1
# Enter higher range  1000
# 1
# 153
# 370
# 371
# 407
