# %%
import random

lower = int(input("Enter lower range: "))
higher = int(input("Enter higher range: "))

res = sum(random.sample(range(lower, higher), 10))

print("Summation list is: " + str(res))
# Out:
# Enter lower range:  1
# Enter higher range:  54
# Summation list is: 253
