# %%
#Program to generate 10 random numbers and print their sum

# %%
import random

sum=0
print("The numbers randomly generated are : \n")
for i in range(0,10):

   x=random.random()
   print(x)
   sum+=x

print("\nThe sum of the random numbers generated = ",sum)
# Out:
# The numbers randomly generated are :
#
# 0.29839797911867105
# 0.6627216366221091
# 0.21722121514876447
# 0.46737652688027
# 0.7274934695962294
# 0.32128426373988805
# 0.6204794453237537
# 0.981253678181466
# 0.5751003576783059
# 0.6250159443924304
#
# The sum of the random numbers generated =  5.496344516681888
