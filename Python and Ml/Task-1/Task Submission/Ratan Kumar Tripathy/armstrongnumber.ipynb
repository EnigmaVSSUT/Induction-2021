# %%
a=int(input('Starting of range'))
b=int(input('Ending of range'))

for x in range(a,b):
    
   
   s = 0

   t = x
   while t > 0:
       r = t % 10
       s =s+ r ** 3
       t=t // 10

   if x == s:
       print(x)
# Out:
# Starting of range 110
# Ending of range 800
# 153
# 370
# 371
# 407
