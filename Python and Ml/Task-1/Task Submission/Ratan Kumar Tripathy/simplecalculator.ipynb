# %%
a=int(input('Enter number'))
b=int(input('Enter other number'))
c=input('Enter mathemcatical operation from +,-,/,*,%')
if c=='+':
    print(a+b)
elif c=='-':
    print(a-b)
elif c=='/':
    print(a/b)
elif c=='*':
    print(a*b)
elif c=='%':
    print(a%b)
# Out:
# Enter number 2
# Enter other number 3
# Enter mathemcatical operation from +,-,/,*,% -
# -1
