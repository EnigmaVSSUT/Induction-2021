# %%
import cmath
a=int(input('enter x*x coefficient'))
b=int(input('enter x coefficient'))
c=int(input('enter constant'))
dis= b**2 - (4*a*c)
a1= (-b-cmath.sqrt(dis))/(2*a)
a2= (-b-cmath.sqrt(dis))/(2*a)
print(a1)
print(a2)
# Out:
# enter x*x coefficient 1
# enter x coefficient 2
# enter constant 3
# (-1-1.4142135623730951j)
# (-1-1.4142135623730951j)
