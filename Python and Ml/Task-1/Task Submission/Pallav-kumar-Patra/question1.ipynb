# %%
import cmath
print("general expression = ax**2 + bx + c")
a= int(input("Enter a(a!=0):"))
b= int(input("Enter b:"))
c= int(input("Enter c:"))

d = (b**2)-(4*a*c)
sol1 = (-b-cmath.sqrt(d))/(2*a)
sol2= (-b+cmath.sqrt(d))/(2*a)
print(sol1)
print(sol2)
# Out:
# general expression = ax**2 + bx + c
# Enter a(a!=0): 1
# Enter b: 10
# Enter c: 4
# (-9.582575694955839+0j)
# (-0.41742430504416017+0j)
