# %%
import random

randomlist=random.sample(range(1, 100), 10)
print(randomlist)
    
sum = sum(randomlist)
  
print ("Random number summation list is : " + str(sum))
# Out:
# [43, 61, 37, 34, 19, 2, 12, 10, 79, 58]
# Random number summation list is : 355
