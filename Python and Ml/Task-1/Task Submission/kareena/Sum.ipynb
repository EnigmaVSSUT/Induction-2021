# %%
import random
def randnums():
    numbers= []
    for count in range(10):
        number = random.randint(1,15)
        numbers.append(number)
        print(number)
        print(sum(numbers))
randnums()
