# %%
lower = int(input("Enter lower range: "))  
upper = int(input("Enter upper range: "))  
  
for num in range(lower,upper + 1):  
   sum = 0  
   t = num  
   while t > 0:  
       digit = t % 10  
       sum += digit ** 3  
       t //= 10  
       if num == sum:  
            print(num)
# Out:
# Enter lower range:  125
# Enter upper range:  320
# 125
# 153
# 216
