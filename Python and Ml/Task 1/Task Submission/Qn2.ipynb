# %%
l=int(input("Enter the lower limit:"))
u=int(input("Enter the upper limit:"))
for i in range(l,u + 1):
    p=len(str(i))
    sum=0
    t=i
    while i>0:
        r=i%10
        sum+=r**p
        i//=10
    if(sum==t):
        print(t)
# Out:
# Enter the lower limit: 1600
# Enter the upper limit: 1700
# 1634
